# %%
import pandas as pd
import os
import shutil
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from pathlib import Path
from IPython.display import display, Audio
import librosa
import librosa.display
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\Korisnik\Anaconda3\lib\site-packages\h5py\__init__.py:72: UserWarning: h5py is running against HDF5 1.10.2 when it was built against 1.10.3, this may cause problems
#   '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
# Using TensorFlow backend.

# %%
#dividing to test, validation and training set
DATASET_AUDIO_PATH = "Data/genres_original/"

class_names = os.listdir(DATASET_AUDIO_PATH)
print("Our class names: {}".format(class_names,))

SHUFFLE_SEED = 43
VALID_and_TEST_SPLIT = 0.2
VALID_SPLIT = 0.5


BATCH_SIZE = 128
EPOCHS = 100
SAMPLING_RATE = 16000

audio_paths = [] # list of paths for every audio sample
labels = [] # classification
features = []
EPS = 1e-8

def extract_features(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, res_type="kaiser_fast")
        #augmentation, siffting
        pitch_shift_audio= librosa.effects.pitch_shift(audio, sample_rate,n_steps=3)
        print("asass21")
        mfccs = librosa.feature.mfcc(y=pitch_shift_audio, n_mfcc=40)
        print("asass12")
        mfccscaled = np.mean(mfccs.T, axis=0)     
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None
  
    return mfccscaled

for index, name in enumerate(class_names):
    dir_path = Path(DATASET_AUDIO_PATH)/name
    for filepath in os.listdir(dir_path):
        if filepath.endswith(".wav"):
            data = extract_features(os.path.join(dir_path, filepath))
            features.append([None, data, name])


features_df = pd.DataFrame(features, columns=["file", "feature", "class_label"])
# Out:
# Our class names: ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12
# asass21
# asass12

# %%
#print(features_df)

# 80:10:10
# Split into training, validation and test
X = np.array(features_df.feature.tolist())
y = np.array(features_df.class_label.tolist())

le = LabelEncoder()
yy = le.fit_transform(y)

x_train, x_test_valid, y_train, y_test_valid = train_test_split(X, yy, test_size=0.2, shuffle=True, random_state=42)
x_valid, x_test, y_valid, y_test = train_test_split(x_test_valid,  y_test_valid, test_size=0.5, shuffle=True, random_state=42)
scaler = preprocessing.StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)

scaler1 = preprocessing.StandardScaler().fit(x_test)
x_test = scaler1.transform(x_test)


scaler2 = preprocessing.StandardScaler().fit(x_valid)
x_valid = scaler2.transform(x_valid)

# %%
# model

from keras.models import Sequential
from keras.layers import Dense,BatchNormalization, Dropout, Activation, Flatten
from keras.optimizers import Adam
from keras.utils import to_categorical


num_classes = 10
y_train = to_categorical(y_train, num_classes=num_classes)
y_valid = to_categorical(y_valid, num_classes=num_classes)
y_test = to_categorical(y_test, num_classes=num_classes)

model = Sequential()

model.add(Dense(128, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dropout(0.25))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(num_classes, activation='softmax'))
#model.compile(optimizer='adam',
#              loss='sparse_categorical_crossentropy',
 #             metrics=['accuracy'])

model.build()
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_34 (Dense)             (None, 128)               5248
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                650
# =================================================================
# Total params: 14,154
# Trainable params: 14,154
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
from datetime import datetime

num_epochs = 100
batch_size = 16

checkpointer = ModelCheckpoint(filepath="best_weights.hdf5", verbose=1, save_best_only=True)

start = datetime.now()

H = model.fit(x_train, y_train, batch_size=batch_size, epochs=num_epochs, validation_data=(x_valid, y_valid), 
          callbacks=[checkpointer], verbose=1)


train_score = model.evaluate(x_train, y_train, verbose=1)
print("Training Accuracy: ", train_score[1])

valid_score = model.evaluate(x_valid, y_valid, verbose=1)
print("Valid Accuracy: ", valid_score[1])
# Out:
# Train on 800 samples, validate on 100 samples
# Epoch 1/100
# 800/800 [==============================] - 0s 474us/step - loss: 2.2063 - accuracy: 0.2087 - val_loss: 2.0116 - val_accuracy: 0.2600
#
# Epoch 00001: val_loss improved from inf to 2.01160, saving model to best_weights.hdf5
# Epoch 2/100
# 800/800 [==============================] - 0s 92us/step - loss: 1.8387 - accuracy: 0.3550 - val_loss: 1.8255 - val_accuracy: 0.3600
#
# Epoch 00002: val_loss improved from 2.01160 to 1.82551, saving model to best_weights.hdf5
# Epoch 3/100
# 800/800 [==============================] - 0s 91us/step - loss: 1.6247 - accuracy: 0.4412 - val_loss: 1.6814 - val_accuracy: 0.3800
#
# Epoch 00003: val_loss improved from 1.82551 to 1.68138, saving model to best_weights.hdf5
# Epoch 4/100
# 800/800 [==============================] - 0s 93us/step - loss: 1.4962 - accuracy: 0.4638 - val_loss: 1.5765 - val_accuracy: 0.3900
#
# Epoch 00004: val_loss improved from 1.68138 to 1.57654, saving model to best_weights.hdf5
# Epoch 5/100
# 800/800 [==============================] - 0s 89us/step - loss: 1.3455 - accuracy: 0.5387 - val_loss: 1.5024 - val_accuracy: 0.4500
#
# Epoch 00005: val_loss improved from 1.57654 to 1.50237, saving model to best_weights.hdf5
# Epoch 6/100
# 800/800 [==============================] - 0s 90us/step - loss: 1.3045 - accuracy: 0.5387 - val_loss: 1.4465 - val_accuracy: 0.5000
#
# Epoch 00006: val_loss improved from 1.50237 to 1.44653, saving model to best_weights.hdf5
# Epoch 7/100
# 800/800 [==============================] - 0s 94us/step - loss: 1.2342 - accuracy: 0.5537 - val_loss: 1.4117 - val_accuracy: 0.4800
#
# Epoch 00007: val_loss improved from 1.44653 to 1.41173, saving model to best_weights.hdf5
# Epoch 8/100
# 800/800 [==============================] - 0s 87us/step - loss: 1.1313 - accuracy: 0.6062 - val_loss: 1.3428 - val_accuracy: 0.5200
#
# Epoch 00008: val_loss improved from 1.41173 to 1.34278, saving model to best_weights.hdf5
# Epoch 9/100
# 800/800 [==============================] - 0s 101us/step - loss: 1.0732 - accuracy: 0.6300 - val_loss: 1.2961 - val_accuracy: 0.5700
#
# Epoch 00009: val_loss improved from 1.34278 to 1.29608, saving model to best_weights.hdf5
# Epoch 10/100
# 800/800 [==============================] - 0s 90us/step - loss: 1.0404 - accuracy: 0.6350 - val_loss: 1.2972 - val_accuracy: 0.5600
#
# Epoch 00010: val_loss did not improve from 1.29608
# Epoch 11/100
# 800/800 [==============================] - 0s 84us/step - loss: 1.0088 - accuracy: 0.6513 - val_loss: 1.2480 - val_accuracy: 0.5500
#
# Epoch 00011: val_loss improved from 1.29608 to 1.24802, saving model to best_weights.hdf5
# Epoch 12/100
# 800/800 [==============================] - 0s 92us/step - loss: 0.9946 - accuracy: 0.6475 - val_loss: 1.2195 - val_accuracy: 0.5800
#
# Epoch 00012: val_loss improved from 1.24802 to 1.21949, saving model to best_weights.hdf5
# Epoch 13/100
# 800/800 [==============================] - 0s 96us/step - loss: 0.9328 - accuracy: 0.6712 - val_loss: 1.2032 - val_accuracy: 0.5800
#
# Epoch 00013: val_loss improved from 1.21949 to 1.20321, saving model to best_weights.hdf5
# Epoch 14/100
# 800/800 [==============================] - 0s 95us/step - loss: 0.9108 - accuracy: 0.6787 - val_loss: 1.1665 - val_accuracy: 0.6000
#
# Epoch 00014: val_loss improved from 1.20321 to 1.16653, saving model to best_weights.hdf5
# Epoch 15/100
# 800/800 [==============================] - 0s 89us/step - loss: 0.8468 - accuracy: 0.6963 - val_loss: 1.1793 - val_accuracy: 0.6000
#
# Epoch 00015: val_loss did not improve from 1.16653
# Epoch 16/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.8308 - accuracy: 0.7138 - val_loss: 1.1923 - val_accuracy: 0.6000
#
# Epoch 00016: val_loss did not improve from 1.16653
# Epoch 17/100
# 800/800 [==============================] - 0s 82us/step - loss: 0.7729 - accuracy: 0.7362 - val_loss: 1.1586 - val_accuracy: 0.5900
#
# Epoch 00017: val_loss improved from 1.16653 to 1.15864, saving model to best_weights.hdf5
# Epoch 18/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.7705 - accuracy: 0.7350 - val_loss: 1.1870 - val_accuracy: 0.5900
#
# Epoch 00018: val_loss did not improve from 1.15864
# Epoch 19/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.7383 - accuracy: 0.7375 - val_loss: 1.1644 - val_accuracy: 0.5800
#
# Epoch 00019: val_loss did not improve from 1.15864
# Epoch 20/100
# 800/800 [==============================] - 0s 83us/step - loss: 0.7423 - accuracy: 0.7337 - val_loss: 1.2104 - val_accuracy: 0.5800
#
# Epoch 00020: val_loss did not improve from 1.15864
# Epoch 21/100
# 800/800 [==============================] - 0s 82us/step - loss: 0.6831 - accuracy: 0.7688 - val_loss: 1.1624 - val_accuracy: 0.6200
#
# Epoch 00021: val_loss did not improve from 1.15864
# Epoch 22/100
# 800/800 [==============================] - 0s 93us/step - loss: 0.6642 - accuracy: 0.7812 - val_loss: 1.1969 - val_accuracy: 0.6200
#
# Epoch 00022: val_loss did not improve from 1.15864
# Epoch 23/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.6416 - accuracy: 0.7775 - val_loss: 1.1392 - val_accuracy: 0.6300
#
# Epoch 00023: val_loss improved from 1.15864 to 1.13917, saving model to best_weights.hdf5
# Epoch 24/100
# 800/800 [==============================] - 0s 81us/step - loss: 0.5957 - accuracy: 0.8050 - val_loss: 1.1806 - val_accuracy: 0.6400
#
# Epoch 00024: val_loss did not improve from 1.13917
# Epoch 25/100
# 800/800 [==============================] - 0s 81us/step - loss: 0.6196 - accuracy: 0.7837 - val_loss: 1.1609 - val_accuracy: 0.6100
#
# Epoch 00025: val_loss did not improve from 1.13917
# Epoch 26/100
# 800/800 [==============================] - 0s 84us/step - loss: 0.6365 - accuracy: 0.7837 - val_loss: 1.2187 - val_accuracy: 0.5800
#
# Epoch 00026: val_loss did not improve from 1.13917
# Epoch 27/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.5979 - accuracy: 0.8163 - val_loss: 1.1796 - val_accuracy: 0.6100
#
# Epoch 00027: val_loss did not improve from 1.13917
# Epoch 28/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.5969 - accuracy: 0.7775 - val_loss: 1.2192 - val_accuracy: 0.6300
#
# Epoch 00028: val_loss did not improve from 1.13917
# Epoch 29/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.5615 - accuracy: 0.8150 - val_loss: 1.2312 - val_accuracy: 0.6000
#
# Epoch 00029: val_loss did not improve from 1.13917
# Epoch 30/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.5594 - accuracy: 0.8112 - val_loss: 1.2273 - val_accuracy: 0.6300
#
# Epoch 00030: val_loss did not improve from 1.13917
# Epoch 31/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.5323 - accuracy: 0.7950 - val_loss: 1.2422 - val_accuracy: 0.6300
#
# Epoch 00031: val_loss did not improve from 1.13917
# Epoch 32/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.5294 - accuracy: 0.8238 - val_loss: 1.1939 - val_accuracy: 0.6400
#
# Epoch 00032: val_loss did not improve from 1.13917
# Epoch 33/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.5146 - accuracy: 0.8313 - val_loss: 1.2272 - val_accuracy: 0.6500
#
# Epoch 00033: val_loss did not improve from 1.13917
# Epoch 34/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.5148 - accuracy: 0.8225 - val_loss: 1.2392 - val_accuracy: 0.6200
#
# Epoch 00034: val_loss did not improve from 1.13917
# Epoch 35/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.4990 - accuracy: 0.8200 - val_loss: 1.2528 - val_accuracy: 0.6000
#
# Epoch 00035: val_loss did not improve from 1.13917
# Epoch 36/100
# 800/800 [==============================] - 0s 84us/step - loss: 0.4701 - accuracy: 0.8363 - val_loss: 1.2572 - val_accuracy: 0.6600
#
# Epoch 00036: val_loss did not improve from 1.13917
# Epoch 37/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.4923 - accuracy: 0.8313 - val_loss: 1.3028 - val_accuracy: 0.5900
#
# Epoch 00037: val_loss did not improve from 1.13917
# Epoch 38/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.4766 - accuracy: 0.8450 - val_loss: 1.2386 - val_accuracy: 0.6100
#
# Epoch 00038: val_loss did not improve from 1.13917
# Epoch 39/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.4259 - accuracy: 0.8525 - val_loss: 1.2926 - val_accuracy: 0.6500
#
# Epoch 00039: val_loss did not improve from 1.13917
# Epoch 40/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.3910 - accuracy: 0.8737 - val_loss: 1.3026 - val_accuracy: 0.6400
#
# Epoch 00040: val_loss did not improve from 1.13917
# Epoch 41/100
# 800/800 [==============================] - 0s 77us/step - loss: 0.4261 - accuracy: 0.8525 - val_loss: 1.3576 - val_accuracy: 0.6400
#
# Epoch 00041: val_loss did not improve from 1.13917
# Epoch 42/100
# 800/800 [==============================] - 0s 81us/step - loss: 0.4344 - accuracy: 0.8462 - val_loss: 1.3292 - val_accuracy: 0.6400
#
# Epoch 00042: val_loss did not improve from 1.13917
# Epoch 43/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.4201 - accuracy: 0.8662 - val_loss: 1.3203 - val_accuracy: 0.6600
#
# Epoch 00043: val_loss did not improve from 1.13917
# Epoch 44/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.4346 - accuracy: 0.8413 - val_loss: 1.3669 - val_accuracy: 0.6200
#
# Epoch 00044: val_loss did not improve from 1.13917
# Epoch 45/100
# 800/800 [==============================] - 0s 82us/step - loss: 0.3763 - accuracy: 0.8750 - val_loss: 1.3083 - val_accuracy: 0.6300
#
# Epoch 00045: val_loss did not improve from 1.13917
# Epoch 46/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.3532 - accuracy: 0.8875 - val_loss: 1.3775 - val_accuracy: 0.6300
#
# Epoch 00046: val_loss did not improve from 1.13917
# Epoch 47/100
# 800/800 [==============================] - 0s 90us/step - loss: 0.3751 - accuracy: 0.8687 - val_loss: 1.3830 - val_accuracy: 0.6500
#
# Epoch 00047: val_loss did not improve from 1.13917
# Epoch 48/100
# 800/800 [==============================] - 0s 77us/step - loss: 0.3438 - accuracy: 0.8700 - val_loss: 1.3691 - val_accuracy: 0.6500
#
# Epoch 00048: val_loss did not improve from 1.13917
# Epoch 49/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.3492 - accuracy: 0.8825 - val_loss: 1.4199 - val_accuracy: 0.6300
#
# Epoch 00049: val_loss did not improve from 1.13917
# Epoch 50/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.3359 - accuracy: 0.8850 - val_loss: 1.3922 - val_accuracy: 0.6200
#
# Epoch 00050: val_loss did not improve from 1.13917
# Epoch 51/100
# 800/800 [==============================] - 0s 77us/step - loss: 0.3510 - accuracy: 0.8888 - val_loss: 1.4428 - val_accuracy: 0.6300
#
# Epoch 00051: val_loss did not improve from 1.13917
# Epoch 52/100
# 800/800 [==============================] - 0s 77us/step - loss: 0.3503 - accuracy: 0.8813 - val_loss: 1.4536 - val_accuracy: 0.6300
#
# Epoch 00052: val_loss did not improve from 1.13917
# Epoch 53/100
# 800/800 [==============================] - 0s 81us/step - loss: 0.3278 - accuracy: 0.8863 - val_loss: 1.4640 - val_accuracy: 0.6300
#
# Epoch 00053: val_loss did not improve from 1.13917
# Epoch 54/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.2879 - accuracy: 0.9087 - val_loss: 1.4767 - val_accuracy: 0.6200
#
# Epoch 00054: val_loss did not improve from 1.13917
# Epoch 55/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.3166 - accuracy: 0.8900 - val_loss: 1.4458 - val_accuracy: 0.6000
#
# Epoch 00055: val_loss did not improve from 1.13917
# Epoch 56/100
# 800/800 [==============================] - 0s 77us/step - loss: 0.2721 - accuracy: 0.9175 - val_loss: 1.4022 - val_accuracy: 0.6400
#
# Epoch 00056: val_loss did not improve from 1.13917
# Epoch 57/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.3175 - accuracy: 0.8800 - val_loss: 1.4975 - val_accuracy: 0.6400
#
# Epoch 00057: val_loss did not improve from 1.13917
# Epoch 58/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.2982 - accuracy: 0.8863 - val_loss: 1.5255 - val_accuracy: 0.6500
#
# Epoch 00058: val_loss did not improve from 1.13917
# Epoch 59/100
# 800/800 [==============================] - 0s 77us/step - loss: 0.2748 - accuracy: 0.9137 - val_loss: 1.5066 - val_accuracy: 0.6400
#
# Epoch 00059: val_loss did not improve from 1.13917
# Epoch 60/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.2781 - accuracy: 0.9112 - val_loss: 1.5301 - val_accuracy: 0.6500
#
# Epoch 00060: val_loss did not improve from 1.13917
# Epoch 61/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.2549 - accuracy: 0.9250 - val_loss: 1.4610 - val_accuracy: 0.6700
#
# Epoch 00061: val_loss did not improve from 1.13917
# Epoch 62/100
# 800/800 [==============================] - 0s 84us/step - loss: 0.2714 - accuracy: 0.9187 - val_loss: 1.5109 - val_accuracy: 0.6700
#
# Epoch 00062: val_loss did not improve from 1.13917
# Epoch 63/100
# 800/800 [==============================] - 0s 82us/step - loss: 0.2675 - accuracy: 0.9112 - val_loss: 1.5293 - val_accuracy: 0.6500
#
# Epoch 00063: val_loss did not improve from 1.13917
# Epoch 64/100
# 800/800 [==============================] - 0s 81us/step - loss: 0.2598 - accuracy: 0.9125 - val_loss: 1.5762 - val_accuracy: 0.6300
#
# Epoch 00064: val_loss did not improve from 1.13917
# Epoch 65/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.2790 - accuracy: 0.9062 - val_loss: 1.5651 - val_accuracy: 0.6400
#
# Epoch 00065: val_loss did not improve from 1.13917
# Epoch 66/100
# 800/800 [==============================] - 0s 77us/step - loss: 0.3001 - accuracy: 0.9000 - val_loss: 1.5605 - val_accuracy: 0.6600
#
# Epoch 00066: val_loss did not improve from 1.13917
# Epoch 67/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.2547 - accuracy: 0.9175 - val_loss: 1.5922 - val_accuracy: 0.6600
#
# Epoch 00067: val_loss did not improve from 1.13917
# Epoch 68/100
# 800/800 [==============================] - 0s 82us/step - loss: 0.2988 - accuracy: 0.8913 - val_loss: 1.6187 - val_accuracy: 0.6600
#
# Epoch 00068: val_loss did not improve from 1.13917
# Epoch 69/100
# 800/800 [==============================] - 0s 82us/step - loss: 0.2187 - accuracy: 0.9287 - val_loss: 1.6474 - val_accuracy: 0.6400
#
# Epoch 00069: val_loss did not improve from 1.13917
# Epoch 70/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.2494 - accuracy: 0.9150 - val_loss: 1.6085 - val_accuracy: 0.6300
#
# Epoch 00070: val_loss did not improve from 1.13917
# Epoch 71/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.2342 - accuracy: 0.9187 - val_loss: 1.6278 - val_accuracy: 0.6400
#
# Epoch 00071: val_loss did not improve from 1.13917
# Epoch 72/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.2464 - accuracy: 0.9112 - val_loss: 1.6435 - val_accuracy: 0.6300
#
# Epoch 00072: val_loss did not improve from 1.13917
# Epoch 73/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.2472 - accuracy: 0.9162 - val_loss: 1.6677 - val_accuracy: 0.6500
#
# Epoch 00073: val_loss did not improve from 1.13917
# Epoch 74/100
# 800/800 [==============================] - 0s 81us/step - loss: 0.2343 - accuracy: 0.9150 - val_loss: 1.6367 - val_accuracy: 0.6400
#
# Epoch 00074: val_loss did not improve from 1.13917
# Epoch 75/100
# 800/800 [==============================] - 0s 81us/step - loss: 0.2436 - accuracy: 0.9225 - val_loss: 1.6704 - val_accuracy: 0.6500
#
# Epoch 00075: val_loss did not improve from 1.13917
# Epoch 76/100
# 800/800 [==============================] - 0s 82us/step - loss: 0.2104 - accuracy: 0.9388 - val_loss: 1.7076 - val_accuracy: 0.6300
#
# Epoch 00076: val_loss did not improve from 1.13917
# Epoch 77/100
# 800/800 [==============================] - 0s 81us/step - loss: 0.2175 - accuracy: 0.9262 - val_loss: 1.6522 - val_accuracy: 0.6500
#
# Epoch 00077: val_loss did not improve from 1.13917
# Epoch 78/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.2099 - accuracy: 0.9325 - val_loss: 1.6337 - val_accuracy: 0.6700
#
# Epoch 00078: val_loss did not improve from 1.13917
# Epoch 79/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.2275 - accuracy: 0.9337 - val_loss: 1.6779 - val_accuracy: 0.6400
#
# Epoch 00079: val_loss did not improve from 1.13917
# Epoch 80/100
# 800/800 [==============================] - 0s 81us/step - loss: 0.2303 - accuracy: 0.9150 - val_loss: 1.6219 - val_accuracy: 0.6500
# Epoch 00080: val_loss did not improve from 1.13917
# Epoch 81/100
# 800/800 [==============================] - 0s 81us/step - loss: 0.1928 - accuracy: 0.9438 - val_loss: 1.7208 - val_accuracy: 0.6500
#
# Epoch 00081: val_loss did not improve from 1.13917
# Epoch 82/100
# 800/800 [==============================] - 0s 83us/step - loss: 0.1923 - accuracy: 0.9350 - val_loss: 1.6873 - val_accuracy: 0.6500
#
# Epoch 00082: val_loss did not improve from 1.13917
# Epoch 83/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.2041 - accuracy: 0.9463 - val_loss: 1.6798 - val_accuracy: 0.6400
#
# Epoch 00083: val_loss did not improve from 1.13917
# Epoch 84/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.1935 - accuracy: 0.9350 - val_loss: 1.6652 - val_accuracy: 0.6600
#
# Epoch 00084: val_loss did not improve from 1.13917
# Epoch 85/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.2330 - accuracy: 0.9212 - val_loss: 1.7228 - val_accuracy: 0.6600
#
# Epoch 00085: val_loss did not improve from 1.13917
# Epoch 86/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.2153 - accuracy: 0.9275 - val_loss: 1.7390 - val_accuracy: 0.6500
#
# Epoch 00086: val_loss did not improve from 1.13917
# Epoch 87/100
# 800/800 [==============================] - 0s 81us/step - loss: 0.2181 - accuracy: 0.9300 - val_loss: 1.7683 - val_accuracy: 0.6400
#
# Epoch 00087: val_loss did not improve from 1.13917
# Epoch 88/100
# 800/800 [==============================] - 0s 77us/step - loss: 0.1907 - accuracy: 0.9375 - val_loss: 1.7171 - val_accuracy: 0.6400
#
# Epoch 00088: val_loss did not improve from 1.13917
# Epoch 89/100
# 800/800 [==============================] - 0s 76us/step - loss: 0.1766 - accuracy: 0.9438 - val_loss: 1.7411 - val_accuracy: 0.6500
#
# Epoch 00089: val_loss did not improve from 1.13917
# Epoch 90/100
# 800/800 [==============================] - 0s 81us/step - loss: 0.1878 - accuracy: 0.9388 - val_loss: 1.7476 - val_accuracy: 0.6400
#
# Epoch 00090: val_loss did not improve from 1.13917
# Epoch 91/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.2079 - accuracy: 0.9350 - val_loss: 1.7335 - val_accuracy: 0.6500
#
# Epoch 00091: val_loss did not improve from 1.13917
# Epoch 92/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.1977 - accuracy: 0.9337 - val_loss: 1.8332 - val_accuracy: 0.6600
#
# Epoch 00092: val_loss did not improve from 1.13917
# Epoch 93/100
# 800/800 [==============================] - 0s 77us/step - loss: 0.1620 - accuracy: 0.9563 - val_loss: 1.7369 - val_accuracy: 0.6400
#
# Epoch 00093: val_loss did not improve from 1.13917
# Epoch 94/100
# 800/800 [==============================] - 0s 76us/step - loss: 0.1822 - accuracy: 0.9362 - val_loss: 1.7633 - val_accuracy: 0.6400
#
# Epoch 00094: val_loss did not improve from 1.13917
# Epoch 95/100
# 800/800 [==============================] - 0s 82us/step - loss: 0.1730 - accuracy: 0.9425 - val_loss: 1.8136 - val_accuracy: 0.6500
#
# Epoch 00095: val_loss did not improve from 1.13917
# Epoch 96/100
# 800/800 [==============================] - 0s 81us/step - loss: 0.1799 - accuracy: 0.9488 - val_loss: 1.7855 - val_accuracy: 0.6300
#
# Epoch 00096: val_loss did not improve from 1.13917
# Epoch 97/100
# 800/800 [==============================] - 0s 80us/step - loss: 0.1819 - accuracy: 0.9388 - val_loss: 1.7796 - val_accuracy: 0.6400
#
# Epoch 00097: val_loss did not improve from 1.13917
# Epoch 98/100
# 800/800 [==============================] - 0s 77us/step - loss: 0.1766 - accuracy: 0.9362 - val_loss: 1.8372 - val_accuracy: 0.6500
#
# Epoch 00098: val_loss did not improve from 1.13917
# Epoch 99/100
# 800/800 [==============================] - 0s 79us/step - loss: 0.1563 - accuracy: 0.9563 - val_loss: 1.7266 - val_accuracy: 0.6500
#
# Epoch 00099: val_loss did not improve from 1.13917
# Epoch 100/100
# 800/800 [==============================] - 0s 77us/step - loss: 0.1612 - accuracy: 0.9413 - val_loss: 1.8104 - val_accuracy: 0.6500
#
# Epoch 00100: val_loss did not improve from 1.13917
# 800/800 [==============================] - 0s 16us/step
# Training Accuracy:  0.9987499713897705
# 100/100 [==============================] - 0s 40us/step
# Valid Accuracy:  0.6499999761581421

# %%
test_loss, test_acc  = model.evaluate(x_test, y_test, batch_size=128)
print("The test loss is :",test_loss, "\nThe test accuracy is :",test_acc)
# Out:
# 100/100 [==============================] - 0s 30us/step
# The test loss is : 1.692509412765503
# The test accuracy is : 0.6200000047683716

# %%
N = 100
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on Music Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
