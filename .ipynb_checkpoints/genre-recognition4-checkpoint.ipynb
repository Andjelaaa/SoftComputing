# %%
import pandas as pd
import os
import shutil
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from pathlib import Path
from IPython.display import display, Audio
import librosa
import librosa.display
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#dividing to test, validation and training set
DATASET_AUDIO_PATH = "Data/genres_original/"

class_names = os.listdir(DATASET_AUDIO_PATH)
print("Our class names: {}".format(class_names,))

SHUFFLE_SEED = 43
VALID_and_TEST_SPLIT = 0.2
VALID_SPLIT = 0.5


BATCH_SIZE = 128
EPOCHS = 100
SAMPLING_RATE = 16000

audio_paths = [] # list of paths for every audio sample
labels = [] # classification
features = []

for index, name in enumerate(class_names):
    dir_path = Path(DATASET_AUDIO_PATH)/name
    for filepath in os.listdir(dir_path):
        if filepath.endswith(".wav"):
            data = extract_features(os.path.join(dir_path, filepath))
            features.append([None, data, name])


features_df = pd.DataFrame(features, columns=["file", "feature", "class_label"])
# Out:
# Our class names: ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
print(features_df)

# 80:10:10
# Split into training, validation and test
X = np.array(features_df.feature.tolist())
y = np.array(features_df.class_label.tolist())

le = LabelEncoder()
yy = le.fit_transform(y)

x_train, x_test_valid, y_train, y_test_valid = train_test_split(X, yy, test_size=0.2, shuffle=True, random_state=42)
x_valid, x_test, y_valid, y_test = train_test_split(x_test_valid,  y_test_valid, test_size=0.5, shuffle=True, random_state=42)

def extract_features(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, res_type="kaiser_fast")
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccscaled = np.mean(mfccs.T, axis=0)
    
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None
    
    return mfccscaled
# Out:
#      file                                            feature class_label
# 0    None  [-113.57065, 121.57179, -19.168142, 42.36642, ...       blues
# 1    None  [-207.5017, 123.991264, 8.955127, 35.877647, 2...       blues
# 2    None  [-90.722595, 140.4463, -29.09389, 31.684334, -...       blues
# 3    None  [-199.5442, 150.0909, 5.6626782, 26.85908, 1.7...       blues
# 4    None  [-160.3377, 126.219635, -35.58781, 22.148071, ...       blues
# 5    None  [-177.77425, 118.20548, -17.56588, 30.762398, ...       blues
# 6    None  [-190.05237, 130.28908, -36.369534, 33.029034,...       blues
# 7    None  [-179.34714, 136.46901, -26.673138, 39.98424, ...       blues
# 8    None  [-121.363945, 122.50668, -14.738196, 46.131065...       blues
# 9    None  [-213.23999, 115.1656, -11.693431, 39.014275, ...       blues
# 10   None  [-173.7925, 137.1867, -23.724049, 26.978432, -...       blues
# 11   None  [-287.92374, 124.01875, 5.469892, 33.65741, 1....       blues
# 12   None  [-207.22331, 132.83055, -15.4288435, 60.970924...       blues
# 13   None  [-209.82616, 124.46322, 10.342454, 47.010906, ...       blues
# 14   None  [-305.65472, 113.08634, 12.114428, 45.033703, ...       blues
# 15   None  [-238.51553, 120.110176, -4.2293587, 42.290695...       blues
# 16   None  [-233.7591, 120.67514, -3.1748059, 39.51848, 3...       blues
# 17   None  [-245.69937, 140.49109, -2.7897542, 60.431435,...       blues
# 18   None  [-252.49301, 104.93711, 15.332313, 42.66697, 6...       blues
# 19   None  [-236.65675, 138.40926, -4.912911, 47.629173, ...       blues
# 20   None  [-230.35765, 127.07833, 7.123447, 39.7749, 1.9...       blues
# 21   None  [-264.7226, 138.86845, 11.194063, 48.50426, 14...       blues
# 22   None  [-233.95625, 136.1457, 3.324411, 48.92853, 8.7...       blues
# 23   None  [-227.22534, 137.78807, -14.499568, 63.56093, ...       blues
# 24   None  [-274.3658, 130.41125, -6.3512874, 70.402985, ...       blues
# 25   None  [-249.28456, 131.00468, 0.67143536, 66.70393, ...       blues
# 26   None  [-284.8484, 108.749565, 9.129683, 51.251312, 1...       blues
# 27   None  [-228.16708, 130.33966, -23.310709, 70.20022, ...       blues
# 28   None  [-248.96225, 139.03177, -16.240025, 57.11619, ...       blues
# 29   None  [-233.7151, 101.19902, 17.6509, 23.740635, 2.0...       blues
# ..    ...                                                ...         ...
# 969  None  [-202.1905, 75.24043, -14.231188, 66.313705, -...        rock
# 970  None  [-79.77386, 109.91621, -17.12, 47.194103, -11....        rock
# 971  None  [-95.342224, 112.45149, -2.079154, 47.04607, -...        rock
# 972  None  [-61.665348, 103.57051, -16.919374, 49.251156,...        rock
# 973  None  [-83.33853, 103.88961, -13.957626, 56.89555, -...        rock
# 974  None  [-113.62223, 94.929504, -4.1125126, 51.767094,...        rock
# 975  None  [-132.35986, 124.679306, -9.6921835, 46.44977,...        rock
# 976  None  [-103.9262, 101.89702, -10.333826, 43.66538, -...        rock
# 977  None  [-131.03685, 110.95929, -2.0900457, 41.79464, ...        rock
# 978  None  [-91.36003, 112.10654, -27.335478, 47.978218, ...        rock
# 979  None  [-87.93524, 93.54094, -23.228315, 48.129375, -...        rock
# 980  None  [-121.42924, 89.53305, -33.491787, 41.956745, ...        rock
# 981  None  [-95.407455, 78.322205, -26.208145, 44.23375, ...        rock
# 982  None  [-119.11598, 107.419685, -10.963198, 58.546917...        rock
# 983  None  [-94.23829, 91.887245, -17.597841, 45.528435, ...        rock
# 984  None  [-185.48325, 98.934875, -36.443687, 44.429764,...        rock
# 985  None  [-160.12549, 88.73069, -35.47055, 47.491367, -...        rock
# 986  None  [-42.63793, 102.98485, -36.875816, 44.521515, ...        rock
# 987  None  [-117.9446, 84.051704, -50.263206, 46.048203, ...        rock
# 988  None  [-156.28372, 130.79143, -25.243067, 43.49084, ...        rock
# 989  None  [-88.981575, 86.20825, -24.397999, 47.08425, -...        rock
# 990  None  [-74.27574, 100.125725, -47.363968, 49.617348,...        rock
# 991  None  [-70.07805, 94.1737, -50.334232, 46.961765, -1...        rock
# 992  None  [-114.75441, 119.28787, -50.73627, 42.612713, ...        rock
# 993  None  [-90.20985, 80.066086, -46.360237, 56.053726, ...        rock
# 994  None  [-153.64096, 109.86465, -23.065697, 59.050125,...        rock
# 995  None  [-142.39203, 116.18963, -32.147167, 49.11784, ...        rock
# 996  None  [-124.95227, 115.177155, -47.97515, 52.814674,...        rock
# 997  None  [-225.00775, 123.64677, -9.7241745, 56.605164,...        rock
# 998  None  [-235.16197, 123.870094, -22.538395, 52.939743...        rock
#
# [999 rows x 3 columns]

# %%
# model

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.optimizers import Adam
from keras.utils import to_categorical


num_classes = 10
y_train = to_categorical(y_train, num_classes=num_classes)
y_valid = to_categorical(y_valid, num_classes=num_classes)
y_test = to_categorical(y_test, num_classes=num_classes)

model = Sequential()

model.add(Dense(128, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(num_classes, activation='softmax'))
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_54 (Dense)             (None, 64)                2624
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_55 (Dense)             (None, 10)                650
# =================================================================
# Total params: 3,274
# Trainable params: 3,274
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
from datetime import datetime

num_epochs = 100
batch_size = 16

checkpointer = ModelCheckpoint(filepath="best_weights.hdf5", verbose=1, save_best_only=True)

start = datetime.now()

model.fit(x_train, y_train, batch_size=batch_size, epochs=num_epochs, validation_data=(x_valid, y_valid), 
          callbacks=[checkpointer], verbose=1)


train_score = model.evaluate(x_train, y_train, verbose=1)
print("Training Accuracy: ", train_score[1])

valid_score = model.evaluate(x_valid, y_valid, verbose=1)
print("Valid Accuracy: ", valid_score[1])
# Out:
# Train on 799 samples, validate on 100 samples
# Epoch 1/100
# 799/799 [==============================] - 0s 182us/step - loss: 22.2228 - accuracy: 0.1539 - val_loss: 9.9334 - val_accuracy: 0.1800
#
# Epoch 00001: val_loss improved from inf to 9.93339, saving model to best_weights.hdf5
# Epoch 2/100
# 799/799 [==============================] - 0s 67us/step - loss: 14.1385 - accuracy: 0.1865 - val_loss: 6.1732 - val_accuracy: 0.2400
#
# Epoch 00002: val_loss improved from 9.93339 to 6.17316, saving model to best_weights.hdf5
# Epoch 3/100
# 799/799 [==============================] - 0s 69us/step - loss: 9.9009 - accuracy: 0.2278 - val_loss: 4.5394 - val_accuracy: 0.2600
#
# Epoch 00003: val_loss improved from 6.17316 to 4.53935, saving model to best_weights.hdf5
# Epoch 4/100
# 799/799 [==============================] - 0s 67us/step - loss: 6.6836 - accuracy: 0.2816 - val_loss: 3.8708 - val_accuracy: 0.4000
#
# Epoch 00004: val_loss improved from 4.53935 to 3.87085, saving model to best_weights.hdf5
# Epoch 5/100
# 799/799 [==============================] - 0s 65us/step - loss: 4.8335 - accuracy: 0.3104 - val_loss: 3.1208 - val_accuracy: 0.3800
#
# Epoch 00005: val_loss improved from 3.87085 to 3.12080, saving model to best_weights.hdf5
# Epoch 6/100
# 799/799 [==============================] - 0s 65us/step - loss: 3.7052 - accuracy: 0.3379 - val_loss: 2.6036 - val_accuracy: 0.3400
#
# Epoch 00006: val_loss improved from 3.12080 to 2.60356, saving model to best_weights.hdf5
# Epoch 7/100
# 799/799 [==============================] - 0s 61us/step - loss: 2.9020 - accuracy: 0.3680 - val_loss: 2.4085 - val_accuracy: 0.4200
#
# Epoch 00007: val_loss improved from 2.60356 to 2.40851, saving model to best_weights.hdf5
# Epoch 8/100
# 799/799 [==============================] - 0s 70us/step - loss: 2.4518 - accuracy: 0.4093 - val_loss: 2.2303 - val_accuracy: 0.4400
#
# Epoch 00008: val_loss improved from 2.40851 to 2.23027, saving model to best_weights.hdf5
# Epoch 9/100
# 799/799 [==============================] - 0s 64us/step - loss: 2.3196 - accuracy: 0.3780 - val_loss: 2.1789 - val_accuracy: 0.4500
#
# Epoch 00009: val_loss improved from 2.23027 to 2.17892, saving model to best_weights.hdf5
# Epoch 10/100
# 799/799 [==============================] - 0s 69us/step - loss: 2.0895 - accuracy: 0.4293 - val_loss: 2.0806 - val_accuracy: 0.4300
#
# Epoch 00010: val_loss improved from 2.17892 to 2.08058, saving model to best_weights.hdf5
# Epoch 11/100
# 799/799 [==============================] - 0s 62us/step - loss: 1.9566 - accuracy: 0.4105 - val_loss: 2.0268 - val_accuracy: 0.4600
#
# Epoch 00011: val_loss improved from 2.08058 to 2.02682, saving model to best_weights.hdf5
# Epoch 12/100
# 799/799 [==============================] - 0s 69us/step - loss: 1.8088 - accuracy: 0.4355 - val_loss: 1.8867 - val_accuracy: 0.5300
#
# Epoch 00012: val_loss improved from 2.02682 to 1.88665, saving model to best_weights.hdf5
# Epoch 13/100
# 799/799 [==============================] - 0s 65us/step - loss: 1.6967 - accuracy: 0.4793 - val_loss: 1.9518 - val_accuracy: 0.5100
#
# Epoch 00013: val_loss did not improve from 1.88665
# Epoch 14/100
# 799/799 [==============================] - 0s 62us/step - loss: 1.7199 - accuracy: 0.4493 - val_loss: 1.8364 - val_accuracy: 0.5400
#
# Epoch 00014: val_loss improved from 1.88665 to 1.83635, saving model to best_weights.hdf5
# Epoch 15/100
# 799/799 [==============================] - 0s 61us/step - loss: 1.7075 - accuracy: 0.4468 - val_loss: 1.8313 - val_accuracy: 0.5300
#
# Epoch 00015: val_loss improved from 1.83635 to 1.83134, saving model to best_weights.hdf5
# Epoch 16/100
# 799/799 [==============================] - 0s 66us/step - loss: 1.5504 - accuracy: 0.4881 - val_loss: 1.6735 - val_accuracy: 0.5600
#
# Epoch 00016: val_loss improved from 1.83134 to 1.67351, saving model to best_weights.hdf5
# Epoch 17/100
# 799/799 [==============================] - 0s 61us/step - loss: 1.4717 - accuracy: 0.4906 - val_loss: 1.7351 - val_accuracy: 0.5100
#
# Epoch 00017: val_loss did not improve from 1.67351
# Epoch 18/100
# 799/799 [==============================] - 0s 62us/step - loss: 1.4941 - accuracy: 0.4881 - val_loss: 1.6819 - val_accuracy: 0.5400
#
# Epoch 00018: val_loss did not improve from 1.67351
# Epoch 19/100
# 799/799 [==============================] - 0s 61us/step - loss: 1.4103 - accuracy: 0.5269 - val_loss: 1.6061 - val_accuracy: 0.5500
#
# Epoch 00019: val_loss improved from 1.67351 to 1.60611, saving model to best_weights.hdf5
# Epoch 20/100
# 799/799 [==============================] - 0s 69us/step - loss: 1.3547 - accuracy: 0.5257 - val_loss: 1.6025 - val_accuracy: 0.4800
#
# Epoch 00020: val_loss improved from 1.60611 to 1.60251, saving model to best_weights.hdf5
# Epoch 21/100
# 799/799 [==============================] - 0s 67us/step - loss: 1.4014 - accuracy: 0.5419 - val_loss: 1.5979 - val_accuracy: 0.5600
#
# Epoch 00021: val_loss improved from 1.60251 to 1.59792, saving model to best_weights.hdf5
# Epoch 22/100
# 799/799 [==============================] - 0s 79us/step - loss: 1.3279 - accuracy: 0.5532 - val_loss: 1.5671 - val_accuracy: 0.5200
#
# Epoch 00022: val_loss improved from 1.59792 to 1.56712, saving model to best_weights.hdf5
# Epoch 23/100
# 799/799 [==============================] - 0s 65us/step - loss: 1.3152 - accuracy: 0.5282 - val_loss: 1.4691 - val_accuracy: 0.5700
#
# Epoch 00023: val_loss improved from 1.56712 to 1.46911, saving model to best_weights.hdf5
# Epoch 24/100
# 799/799 [==============================] - 0s 62us/step - loss: 1.2568 - accuracy: 0.5732 - val_loss: 1.5526 - val_accuracy: 0.5400
#
# Epoch 00024: val_loss did not improve from 1.46911
# Epoch 25/100
# 799/799 [==============================] - 0s 61us/step - loss: 1.2091 - accuracy: 0.5620 - val_loss: 1.4905 - val_accuracy: 0.5700
#
# Epoch 00025: val_loss did not improve from 1.46911
# Epoch 26/100
# 799/799 [==============================] - 0s 64us/step - loss: 1.1958 - accuracy: 0.5720 - val_loss: 1.4749 - val_accuracy: 0.5800
#
# Epoch 00026: val_loss did not improve from 1.46911
# Epoch 27/100
# 799/799 [==============================] - 0s 61us/step - loss: 1.1792 - accuracy: 0.5707 - val_loss: 1.4789 - val_accuracy: 0.6000
#
# Epoch 00027: val_loss did not improve from 1.46911
# Epoch 28/100
# 799/799 [==============================] - 0s 61us/step - loss: 1.1862 - accuracy: 0.5845 - val_loss: 1.4719 - val_accuracy: 0.5700
#
# Epoch 00028: val_loss did not improve from 1.46911
# Epoch 29/100
# 799/799 [==============================] - 0s 61us/step - loss: 1.1604 - accuracy: 0.6170 - val_loss: 1.4729 - val_accuracy: 0.6100
#
# Epoch 00029: val_loss did not improve from 1.46911
# Epoch 30/100
# 799/799 [==============================] - 0s 60us/step - loss: 1.1179 - accuracy: 0.5832 - val_loss: 1.3927 - val_accuracy: 0.6000
#
# Epoch 00030: val_loss improved from 1.46911 to 1.39266, saving model to best_weights.hdf5
# Epoch 31/100
# 799/799 [==============================] - 0s 62us/step - loss: 1.1565 - accuracy: 0.6108 - val_loss: 1.4191 - val_accuracy: 0.6000
#
# Epoch 00031: val_loss did not improve from 1.39266
# Epoch 32/100
# 799/799 [==============================] - 0s 61us/step - loss: 1.1032 - accuracy: 0.6095 - val_loss: 1.4428 - val_accuracy: 0.5800
#
# Epoch 00032: val_loss did not improve from 1.39266
# Epoch 33/100
# 799/799 [==============================] - 0s 60us/step - loss: 1.0775 - accuracy: 0.6095 - val_loss: 1.4180 - val_accuracy: 0.6000
#
# Epoch 00033: val_loss did not improve from 1.39266
# Epoch 34/100
# 799/799 [==============================] - 0s 60us/step - loss: 1.0691 - accuracy: 0.6008 - val_loss: 1.3714 - val_accuracy: 0.5900
#
# Epoch 00034: val_loss improved from 1.39266 to 1.37143, saving model to best_weights.hdf5
# Epoch 35/100
# 799/799 [==============================] - 0s 60us/step - loss: 1.0303 - accuracy: 0.6408 - val_loss: 1.3817 - val_accuracy: 0.5900
#
# Epoch 00035: val_loss did not improve from 1.37143
# Epoch 36/100
# 799/799 [==============================] - 0s 64us/step - loss: 1.0476 - accuracy: 0.6008 - val_loss: 1.3825 - val_accuracy: 0.6200
#
# Epoch 00036: val_loss did not improve from 1.37143
# Epoch 37/100
# 799/799 [==============================] - 0s 67us/step - loss: 1.0043 - accuracy: 0.6283 - val_loss: 1.3875 - val_accuracy: 0.6100
#
# Epoch 00037: val_loss did not improve from 1.37143
# Epoch 38/100
# 799/799 [==============================] - 0s 66us/step - loss: 0.9907 - accuracy: 0.6483 - val_loss: 1.3323 - val_accuracy: 0.6300
#
# Epoch 00038: val_loss improved from 1.37143 to 1.33229, saving model to best_weights.hdf5
# Epoch 39/100
# 799/799 [==============================] - 0s 70us/step - loss: 0.9959 - accuracy: 0.6496 - val_loss: 1.3298 - val_accuracy: 0.6100
#
# Epoch 00039: val_loss improved from 1.33229 to 1.32976, saving model to best_weights.hdf5
# Epoch 40/100
# 799/799 [==============================] - 0s 65us/step - loss: 0.9950 - accuracy: 0.6471 - val_loss: 1.3590 - val_accuracy: 0.6500
#
# Epoch 00040: val_loss did not improve from 1.32976
# Epoch 41/100
# 799/799 [==============================] - 0s 60us/step - loss: 1.0048 - accuracy: 0.6671 - val_loss: 1.3737 - val_accuracy: 0.6200
#
# Epoch 00041: val_loss did not improve from 1.32976
# Epoch 42/100
# 799/799 [==============================] - 0s 59us/step - loss: 0.9430 - accuracy: 0.6571 - val_loss: 1.3379 - val_accuracy: 0.5900
#
# Epoch 00042: val_loss did not improve from 1.32976
# Epoch 43/100
# 799/799 [==============================] - 0s 66us/step - loss: 0.9626 - accuracy: 0.6608 - val_loss: 1.3313 - val_accuracy: 0.6500
#
# Epoch 00043: val_loss did not improve from 1.32976
# Epoch 44/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.9002 - accuracy: 0.6884 - val_loss: 1.3589 - val_accuracy: 0.6300
#
# Epoch 00044: val_loss did not improve from 1.32976
# Epoch 45/100
# 799/799 [==============================] - 0s 65us/step - loss: 0.9168 - accuracy: 0.6783 - val_loss: 1.3615 - val_accuracy: 0.6200
#
# Epoch 00045: val_loss did not improve from 1.32976
# Epoch 46/100
# 799/799 [==============================] - 0s 65us/step - loss: 0.9277 - accuracy: 0.6658 - val_loss: 1.3412 - val_accuracy: 0.6400
#
# Epoch 00046: val_loss did not improve from 1.32976
# Epoch 47/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.8962 - accuracy: 0.6771 - val_loss: 1.2821 - val_accuracy: 0.6400
#
# Epoch 00047: val_loss improved from 1.32976 to 1.28210, saving model to best_weights.hdf5
# Epoch 48/100
# 799/799 [==============================] - 0s 62us/step - loss: 0.8732 - accuracy: 0.6821 - val_loss: 1.3092 - val_accuracy: 0.6300
#
# Epoch 00048: val_loss did not improve from 1.28210
# Epoch 49/100
# 799/799 [==============================] - 0s 62us/step - loss: 0.8861 - accuracy: 0.6921 - val_loss: 1.3074 - val_accuracy: 0.6600
#
# Epoch 00049: val_loss did not improve from 1.28210
# Epoch 50/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.8657 - accuracy: 0.6921 - val_loss: 1.3127 - val_accuracy: 0.6300
#
# Epoch 00050: val_loss did not improve from 1.28210
# Epoch 51/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.8498 - accuracy: 0.6909 - val_loss: 1.3476 - val_accuracy: 0.6200
#
# Epoch 00051: val_loss did not improve from 1.28210
# Epoch 52/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.7874 - accuracy: 0.7046 - val_loss: 1.3549 - val_accuracy: 0.6200
#
# Epoch 00052: val_loss did not improve from 1.28210
# Epoch 53/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.8397 - accuracy: 0.6946 - val_loss: 1.2744 - val_accuracy: 0.6900
#
# Epoch 00053: val_loss improved from 1.28210 to 1.27444, saving model to best_weights.hdf5
# Epoch 54/100
# 799/799 [==============================] - 0s 62us/step - loss: 0.8343 - accuracy: 0.7046 - val_loss: 1.3574 - val_accuracy: 0.6400
#
# Epoch 00054: val_loss did not improve from 1.27444
# Epoch 55/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.8227 - accuracy: 0.7021 - val_loss: 1.2788 - val_accuracy: 0.6900
#
# Epoch 00055: val_loss did not improve from 1.27444
# Epoch 56/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.7954 - accuracy: 0.7171 - val_loss: 1.3068 - val_accuracy: 0.6400
#
# Epoch 00056: val_loss did not improve from 1.27444
# Epoch 57/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.8178 - accuracy: 0.6996 - val_loss: 1.3192 - val_accuracy: 0.6700
#
# Epoch 00057: val_loss did not improve from 1.27444
# Epoch 58/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.7615 - accuracy: 0.7384 - val_loss: 1.3290 - val_accuracy: 0.6600
#
# Epoch 00058: val_loss did not improve from 1.27444
# Epoch 59/100
# 799/799 [==============================] - 0s 62us/step - loss: 0.7877 - accuracy: 0.7171 - val_loss: 1.2711 - val_accuracy: 0.6600
#
# Epoch 00059: val_loss improved from 1.27444 to 1.27111, saving model to best_weights.hdf5
# Epoch 60/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.7582 - accuracy: 0.7184 - val_loss: 1.3155 - val_accuracy: 0.6800
#
# Epoch 00060: val_loss did not improve from 1.27111
# Epoch 61/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.8261 - accuracy: 0.6959 - val_loss: 1.3234 - val_accuracy: 0.6800
#
# Epoch 00061: val_loss did not improve from 1.27111
# Epoch 62/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.7545 - accuracy: 0.7347 - val_loss: 1.3734 - val_accuracy: 0.6200
#
# Epoch 00062: val_loss did not improve from 1.27111
# Epoch 63/100
# 799/799 [==============================] - 0s 62us/step - loss: 0.7873 - accuracy: 0.7071 - val_loss: 1.3319 - val_accuracy: 0.6800
#
# Epoch 00063: val_loss did not improve from 1.27111
# Epoch 64/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.7546 - accuracy: 0.7334 - val_loss: 1.3392 - val_accuracy: 0.6700
#
# Epoch 00064: val_loss did not improve from 1.27111
# Epoch 65/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.7931 - accuracy: 0.6971 - val_loss: 1.2910 - val_accuracy: 0.6700
#
# Epoch 00065: val_loss did not improve from 1.27111
# Epoch 66/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.7153 - accuracy: 0.7297 - val_loss: 1.3077 - val_accuracy: 0.6600
#
# Epoch 00066: val_loss did not improve from 1.27111
# Epoch 67/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.6947 - accuracy: 0.7447 - val_loss: 1.3080 - val_accuracy: 0.6600
#
# Epoch 00067: val_loss did not improve from 1.27111
# Epoch 68/100
# 799/799 [==============================] - 0s 62us/step - loss: 0.7415 - accuracy: 0.7372 - val_loss: 1.3157 - val_accuracy: 0.6600
#
# Epoch 00068: val_loss did not improve from 1.27111
# Epoch 69/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.6993 - accuracy: 0.7447 - val_loss: 1.3047 - val_accuracy: 0.6700
#
# Epoch 00069: val_loss did not improve from 1.27111
# Epoch 70/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.7171 - accuracy: 0.7522 - val_loss: 1.3201 - val_accuracy: 0.6800
#
# Epoch 00070: val_loss did not improve from 1.27111
# Epoch 71/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.6982 - accuracy: 0.7522 - val_loss: 1.3054 - val_accuracy: 0.6900
#
# Epoch 00071: val_loss did not improve from 1.27111
# Epoch 72/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.6586 - accuracy: 0.7584 - val_loss: 1.3314 - val_accuracy: 0.6800
#
# Epoch 00072: val_loss did not improve from 1.27111
# Epoch 73/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.6800 - accuracy: 0.7660 - val_loss: 1.3417 - val_accuracy: 0.6900
#
# Epoch 00073: val_loss did not improve from 1.27111
# Epoch 74/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.6522 - accuracy: 0.7635 - val_loss: 1.3396 - val_accuracy: 0.6700
#
# Epoch 00074: val_loss did not improve from 1.27111
# Epoch 75/100
# 799/799 [==============================] - 0s 64us/step - loss: 0.6525 - accuracy: 0.7572 - val_loss: 1.3442 - val_accuracy: 0.6900
#
# Epoch 00075: val_loss did not improve from 1.27111
# Epoch 76/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.6584 - accuracy: 0.7584 - val_loss: 1.3418 - val_accuracy: 0.6700
#
# Epoch 00076: val_loss did not improve from 1.27111
# Epoch 77/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.6593 - accuracy: 0.7610 - val_loss: 1.4006 - val_accuracy: 0.6800
#
# Epoch 00077: val_loss did not improve from 1.27111
# Epoch 78/100
# 799/799 [==============================] - 0s 66us/step - loss: 0.6637 - accuracy: 0.7597 - val_loss: 1.3503 - val_accuracy: 0.6600
# Epoch 00078: val_loss did not improve from 1.27111
# Epoch 79/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.6522 - accuracy: 0.7472 - val_loss: 1.3124 - val_accuracy: 0.6800
#
# Epoch 00079: val_loss did not improve from 1.27111
# Epoch 80/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.6282 - accuracy: 0.7660 - val_loss: 1.4240 - val_accuracy: 0.6600
#
# Epoch 00080: val_loss did not improve from 1.27111
# Epoch 81/100
# 799/799 [==============================] - 0s 59us/step - loss: 0.6549 - accuracy: 0.7597 - val_loss: 1.3495 - val_accuracy: 0.6700
#
# Epoch 00081: val_loss did not improve from 1.27111
# Epoch 82/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.6365 - accuracy: 0.7647 - val_loss: 1.3255 - val_accuracy: 0.6700
#
# Epoch 00082: val_loss did not improve from 1.27111
# Epoch 83/100
# 799/799 [==============================] - 0s 59us/step - loss: 0.6106 - accuracy: 0.7860 - val_loss: 1.3838 - val_accuracy: 0.7000
#
# Epoch 00083: val_loss did not improve from 1.27111
# Epoch 84/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.6407 - accuracy: 0.7685 - val_loss: 1.4503 - val_accuracy: 0.6700
#
# Epoch 00084: val_loss did not improve from 1.27111
# Epoch 85/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.6162 - accuracy: 0.7785 - val_loss: 1.3746 - val_accuracy: 0.6900
#
# Epoch 00085: val_loss did not improve from 1.27111
# Epoch 86/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.6057 - accuracy: 0.7897 - val_loss: 1.3678 - val_accuracy: 0.7200
#
# Epoch 00086: val_loss did not improve from 1.27111
# Epoch 87/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.6086 - accuracy: 0.7910 - val_loss: 1.4247 - val_accuracy: 0.7000
#
# Epoch 00087: val_loss did not improve from 1.27111
# Epoch 88/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.6646 - accuracy: 0.7735 - val_loss: 1.3332 - val_accuracy: 0.7200
#
# Epoch 00088: val_loss did not improve from 1.27111
# Epoch 89/100
# 799/799 [==============================] - 0s 62us/step - loss: 0.5818 - accuracy: 0.7897 - val_loss: 1.3540 - val_accuracy: 0.6500
#
# Epoch 00089: val_loss did not improve from 1.27111
# Epoch 90/100
# 799/799 [==============================] - 0s 62us/step - loss: 0.5885 - accuracy: 0.7885 - val_loss: 1.4632 - val_accuracy: 0.6600
#
# Epoch 00090: val_loss did not improve from 1.27111
# Epoch 91/100
# 799/799 [==============================] - 0s 61us/step - loss: 0.6299 - accuracy: 0.7697 - val_loss: 1.4189 - val_accuracy: 0.7000
#
# Epoch 00091: val_loss did not improve from 1.27111
# Epoch 92/100
# 799/799 [==============================] - 0s 62us/step - loss: 0.6126 - accuracy: 0.7660 - val_loss: 1.3588 - val_accuracy: 0.6800
#
# Epoch 00092: val_loss did not improve from 1.27111
# Epoch 93/100
# 799/799 [==============================] - 0s 60us/step - loss: 0.5751 - accuracy: 0.7922 - val_loss: 1.4808 - val_accuracy: 0.6500
#
# Epoch 00093: val_loss did not improve from 1.27111
# Epoch 94/100
# 799/799 [==============================] - 0s 62us/step - loss: 0.5513 - accuracy: 0.8023 - val_loss: 1.3492 - val_accuracy: 0.6800
#
# Epoch 00094: val_loss did not improve from 1.27111
# Epoch 95/100
# 799/799 [==============================] - 0s 62us/step - loss: 0.5975 - accuracy: 0.7897 - val_loss: 1.3446 - val_accuracy: 0.7000
#
# Epoch 00095: val_loss did not improve from 1.27111
# Epoch 96/100
# 799/799 [==============================] - 0s 62us/step - loss: 0.5689 - accuracy: 0.8035 - val_loss: 1.3816 - val_accuracy: 0.6800
#
# Epoch 00096: val_loss did not improve from 1.27111
# Epoch 97/100
# 799/799 [==============================] - 0s 59us/step - loss: 0.6240 - accuracy: 0.7835 - val_loss: 1.4276 - val_accuracy: 0.7000
#
# Epoch 00097: val_loss did not improve from 1.27111
# Epoch 98/100
# 799/799 [==============================] - 0s 64us/step - loss: 0.5971 - accuracy: 0.7985 - val_loss: 1.3521 - val_accuracy: 0.6800
#
# Epoch 00098: val_loss did not improve from 1.27111
# Epoch 99/100
# 799/799 [==============================] - 0s 59us/step - loss: 0.5861 - accuracy: 0.7997 - val_loss: 1.4151 - val_accuracy: 0.6900
#
# Epoch 00099: val_loss did not improve from 1.27111
# Epoch 100/100
# 799/799 [==============================] - 0s 62us/step - loss: 0.5552 - accuracy: 0.8073 - val_loss: 1.3427 - val_accuracy: 0.7200
#
# Epoch 00100: val_loss did not improve from 1.27111
# 799/799 [==============================] - 0s 17us/step
# Training Accuracy:  0.9036295413970947
# 100/100 [==============================] - 0s 30us/step
# Valid Accuracy:  0.7200000286102295

# %%
test_loss, test_acc  = model.evaluate(x_test, y_test, batch_size=128)
print("The test loss is :",test_loss, "\nThe test accuracy is :",test_acc)
# Out:
# 100/100 [==============================] - 0s 12us/step
# The test loss is : 1.6110669374465942
# The test accuracy is : 0.5799999833106995
